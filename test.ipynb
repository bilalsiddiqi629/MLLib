# %%
import numpy as np
from MLLib import MLLib 
import pandas as pd

# %%
data1 = pd.read_csv('U.S._Chronic_Disease_Indicators.csv')

data1.dropna(axis=1, inplace=True)
Y2 = data1['StratificationID1']
X2 = data1.drop('StratificationID1', axis=1)

#titanic_y = titanic_train['Survived']
#titanic_x = titanic_train.drop('Survived', axis=1)

lin = MLLib(X2, Y2)

trainX, trainY, testX, testY = lin.train_test_split(50)
lin.encode()

lin.linreg_train(trainX, trainY)

#print(f"Actual value is {testY[5]}, and the predicted value is {lin.linreg_predict(testX[5])}")
#print()

#Add custom scaler and imputer methods but ts is working for now YAY
